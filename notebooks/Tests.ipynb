# %%
# %cd /homes/kb658/PhraseBuilder/
# Out:
# /homes/kb658/PhraseBuilder
# /homes/kb658/.conda/envs/music/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import yaml
import jsonlines

config_path = "/homes/kb658/PhraseBuilder/configs/configs_os.yaml"

# Load config file
with open(config_path, 'r') as f:
    configs = yaml.safe_load(f)
    
artifact_folder = configs["raw_data"]["artifact_folder"]
mono_folder = configs["raw_data"]["mono_folder"]
json_folder = configs["raw_data"]["json_folder"]
raw_data_folders = configs["raw_data"]["raw_data_folders"]

# %%
def load_jsonl(file_path):
    data = []
    with jsonlines.open(file_path) as reader:
        for line in reader:
            data.append(line)
    return data

total_phrases_in_all_datasets = 0
total_notes_in_all_datasets = 0
total_songs_in_all_datasets = 0

for dataset_name, dataset_info in raw_data_folders.items():
    print("Dataset: ", dataset_name)
    annotation_file = load_jsonl(dataset_info.get('annotation_filepath'))
    total_phrases_per_song = 0
    total_notes_per_song = 0
    total_songs = 0
    for i in range(len(annotation_file)):
        total_phrases = sum([1 for x in annotation_file[i]["features"]["phrase_end"] if x == True])
        if total_phrases > 1:
            total_phrases_per_song += total_phrases
            total_notes_per_song += len(annotation_file[i]["features"]["phrase_end"])
            total_songs += 1

            total_phrases_in_all_datasets += total_phrases
            total_notes_in_all_datasets += len(annotation_file[i]["features"]["phrase_end"])
            total_songs_in_all_datasets += 1

    print("Total phrases per song: ", total_phrases_per_song)
    print("Total notes per song: ", total_notes_per_song)

    # Average number of phrases per song
    print("Average number of phrases per song: ", total_phrases_per_song/total_songs)
    # Average number of notes per song
    print("Average number of notes per song: ", total_notes_per_song/total_songs)

    print("Total songs: ", total_songs)

print("Total phrases in all datasets: ", total_phrases_in_all_datasets)
print("Total notes in all datasets: ", total_notes_in_all_datasets)
print("Total songs in all datasets: ", total_songs_in_all_datasets)
# Out:
# Dataset:  dataset_1
# Total phrases per song:  47356
# Total notes per song:  444319
# Average number of phrases per song:  5.606914515747099
# Average number of notes per song:  52.60703291498935
# Total songs:  8446
# Dataset:  dataset_2
# Total phrases per song:  1890
# Total notes per song:  17304
# Average number of phrases per song:  5.25
# Average number of notes per song:  48.06666666666667
# Total songs:  360
# Dataset:  dataset_3
# Total phrases per song:  111681
# Total notes per song:  1293990
# Average number of phrases per song:  6.191772467705272
# Average number of notes per song:  71.74086599767145
# Total songs:  18037
# Total phrases in all datasets:  160927
# Total notes in all datasets:  1755613
# Total songs in all datasets:  26843

# %%
print("Average number of phrases per song in all datasets: ", total_phrases_in_all_datasets/total_songs_in_all_datasets)
print("Average number of notes per song in all datasets: ", total_notes_in_all_datasets/total_songs_in_all_datasets)
# Out:
# Average number of phrases per song in all datasets:  5.995119770517453
# Average number of notes per song in all datasets:  65.4030100957419

# %%
dataset_info
# Out:
# {'folder_path': 'C:/Users/Keshav/Desktop/QMUL/Research/Datasets/MTC/essen',
#  'file_extension': 'krn',
#  'annotation_filepath': 'data/annotations/essen_sequences-1.1.jsonl/essen_sequences.jsonl'}

# %%
print(annotation_file[0]["features"]["phrase_end"])
# Count number of True values in phrase_end
total_phrases = sum([1 for x in annotation_file[0]["features"]["phrase_end"] if x == True])
print(total_phrases)
# Out:
# [False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True]
# 5

# %%
i=0
print(annotation_file[i]['features']['timesignature'])
print(annotation_file[i]['features']['duration'])
print(annotation_file[i]['features']['duration_fullname'])
# Out:
# ['6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8', '6/8']
# [0.75, 0.25, 0.5, 0.75, 0.25, 0.5, 0.75, 0.25, 0.5, 1.0, 1.0, 0.5, 1.0, 0.5, 1.5, 1.0, 1.0, 0.5, 1.0, 0.5, 1.0, 0.5, 1.5, 1.0, 0.5, 1.0, 0.5, 0.75, 0.25, 0.5, 1.0, 1.0, 0.5, 1.0, 0.5, 1.0, 0.5, 1.0, 0.5, 2.5, 0.5, 1.0]
# ...

# %%
i=1
print(annotation_file[i]['features']['timesignature'])
print(annotation_file[i]['features']['duration'])
print(annotation_file[i]['features']['duration_fullname'])
# Out:
# ['3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4', '3/4']
# [1.0, 0.5, 0.5, 1.0, 1.0, 0.5, 0.5, 1.0, 1.0, 0.5, 0.5, 1.0, 1.0, 2.0, 1.0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 1.0, 1.0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 2.0, 0.25, 0.25, 0.5, 0.5, 0.5, 1.0, 0.25, 0.25, 0.5, 0.5, 0.5, 1.0, 0.25, 0.25, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 2.0]
# ...

# %%
i=2
print(annotation_file[i]['features']['timesignature'])
print(annotation_file[i]['features']['duration'])
print(annotation_file[i]['features']['duration_fullname'])
# Out:
# ['4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4', '4/4']
# [0.5, 0.5, 1.0, 1.0, 1.0, 0.5, 0.5, 1.0, 0.5, 0.5, 1.0, 0.5, 0.5, 1.0, 0.5, 0.5, 0.5, 0.5, 1.0, 2.0, 1.0, 1.0, 0.5, 0.5, 1.0, 0.5, 0.5, 0.5, 0.5, 1.0, 1.5, 0.5, 1.0, 1.0, 1.5, 0.5, 1.5, 0.5, 1.0, 1.0, 2.0]
# ['Eighth', 'Eighth', 'Quarter', 'Quarter', 'Quarter', 'Eighth', 'Eighth', 'Quarter', 'Eighth', 'Eighth', 'Quarter', 'Eighth', 'Eighth', 'Quarter', 'Eighth', 'Eighth', 'Eighth', 'Eighth', 'Quarter', 'Half', 'Quarter', 'Quarter', 'Eighth', 'Eighth', 'Quarter', 'Eighth', 'Eighth', 'Eighth', 'Eighth', 'Quarter', 'Dotted Quarter', 'Eighth', 'Quarter', 'Quarter', 'Dotted Quarter', 'Eighth', 'Dotted Quarter', 'Eighth', 'Quarter', 'Quarter', 'Half']

# %%
i = 1105

time_signature = annotation_file[i]['features']['timesignature'][0]
numerator = int(time_signature.split("/")[0])
denominator = int(time_signature.split("/")[1])
if denominator == 4:
    beats_in_bar = numerator * (denominator / 8) * 2
elif denominator == 8:
    beats_in_bar = numerator * (denominator / 8) / 2
elif denominator == 2:
    beats_in_bar = numerator * (denominator / 8) * 8
elif denominator == 1:
    beats_in_bar = numerator * (denominator / 8) * 32
print(time_signature, beats_in_bar)
    
pitches = annotation_file[i]['features']['midipitch']
durations = annotation_file[i]['features']['duration']
next_note_rest_value = annotation_file[i]['features']['restduration_frac']

encoding = []
bar = 0
onset = 0
for idx, pitch_value in enumerate(pitches):
    note_info = []
    if idx == 0:
        note_info.append([bar, onset, 0, pitches[idx], durations[idx], 91])
    else:
        # Check if previous note was a rest
        prev_rest = next_note_rest_value[idx-1]
        if prev_rest is None:
            rest = 0
        else:            
            if "/" in prev_rest:
                rest = float(int(prev_rest.split("/")[0]) / int(prev_rest.split("/")[1]))
            else:
                rest = int(prev_rest)
        
        onset += durations[idx-1] + rest  
        
        if onset >= beats_in_bar:
            previous_onset = encoding[-1][1]
            onset = (previous_onset + durations[idx-1] + rest) % beats_in_bar
            bar += 1
        note_info.append([bar, onset, 0, pitches[idx], durations[idx], 91])
    encoding+=note_info
    
encoding
# Out:
# 4/4 4.0
# [[0, 0, 0, 55, 1.0, 91],
#  [0, 1.5, 0, 55, 0.5, 91],
#  [0, 2.0, 0, 55, 1.0, 91],
#  [0, 3.5, 0, 55, 0.5, 91],
#  [1, 0.0, 0, 60, 1.0, 91],
#  [1, 1.0, 0, 52, 1.0, 91],
#  [1, 2.0, 0, 55, 0.5, 91],
#  [1, 2.5, 0, 53, 0.5, 91],
#  [1, 3.0, 0, 53, 0.5, 91],
#  [2, 0.0, 0, 58, 1.0, 91],
#  [2, 1.0, 0, 58, 1.0, 91],
#  [2, 2.0, 0, 57, 0.5, 91],
#  [2, 2.5, 0, 59, 0.5, 91],
#  [2, 3.0, 0, 60, 0.5, 91],
#  [2, 3.5, 0, 55, 0.5, 91],
#  [3, 0.0, 0, 55, 1.0, 91],
#  [3, 1.0, 0, 53, 1.0, 91],
#  [3, 2.0, 0, 52, 1.0, 91],
#  [4, 0.0, 0, 55, 1.0, 91],
#  [4, 1.0, 0, 55, 1.0, 91],
#  [4, 2.0, 0, 55, 0.5, 91],
#  [4, 2.5, 0, 54, 0.5, 91],
#  [4, 3.0, 0, 54, 1.0, 91],
#  [5, 0.0, 0, 60, 1.0, 91],
#  [5, 1.0, 0, 60, 1.0, 91],
#  [5, 2.0, 0, 60, 0.5, 91],
#  [5, 2.5, 0, 59, 0.5, 91],
#  [5, 3.0, 0, 59, 0.5, 91],
#  [6, 0.0, 0, 62, 1.0, 91],
#  [6, 1.0, 0, 62, 1.0, 91],
#  [6, 2.0, 0, 62, 0.5, 91],
#  [6, 2.5, 0, 52, 0.5, 91],
#  [6, 3.0, 0, 60, 0.5, 91],
#  [6, 3.5, 0, 57, 0.5, 91],
# ...

# %%
from music21 import stream, meter, note, metadata, tempo

def encoding_to_midi(encoding, tempo, time_signature):

    # Create a Score
    score = stream.Score()
    score.metadata = metadata.Metadata()
    score.metadata.title = "Your MIDI Score"

    # Create a Part for the instrument
    part = stream.Part()

    # Set the initial tempo
    initial_tempo = tempo_info.get(0, 120)
    part.append(tempo.MetronomeMark(number=initial_tempo))

    # Set the time signature
    time_signature = meter.TimeSignature(time_signature)

    # Add the time signature to the Part
    part.append(time_signature)

    # Iterate through the MIDI data and create Note objects
    for entry in encoding:
        bar_number, onset_position, instrument_number, pitch, duration, velocity = entry

        # Create a Note
        n = note.Note(pitch, quarterLength=duration)
        n.volume.velocity = velocity

        # Calculate the offset position
        offset_position = bar_number * time_signature.barDuration.quarterLength + onset_position

        # Add the Note to the Part at the calculated offset position
        part.insert(offset_position, n)

        # Check if there is a tempo change for the next bar
        next_tempo = tempo_info.get(bar_number + 1, None)
        if next_tempo is not None:
            part.append(tempo.MetronomeMark(number=next_tempo))

    # Add the Part to the Score
    score.append(part)

    # Write the Score to a MIDI file
    midi_file_path = "output.mid"
    score.write('midi', fp=midi_file_path)

    print(f"MIDI file '{midi_file_path}' generated successfully.")

# %%
# Tempo information as a dictionary {bar_number: tempo}
tempo_info = {0: 120, 2: 100}

encoding_to_midi(encoding, tempo, time_signature)
# Out:
# MIDI file 'output.mid' generated successfully.

# %% [markdown]
# # MidiTok Compund Representation

# %%
# Get the current working directory
cwd = os.getcwd()

# Change the working directory to one level up
import os
os.chdir(cwd + "/..")
print(os.getcwd())
# Out:
# c:\Users\Keshav\Desktop\QMUL\Research\PhraseBuilder_new\PhraseBuilder

# %%
# Load a random MIDI file from mono folder

import glob
import random

midi_files = glob.glob(mono_folder + "/*.mid")
random_midi_file = random.choice(midi_files)
print(random_midi_file)
# Out:
# data\Mono_Midi_Files\deut2711_mono.mid

# %%
# Load the MIDI file using miditok
from miditok import CPWord, TokenizerConfig

# Our parameters
TOKENIZER_PARAMS = {
    "pitch_range": (21, 109),
    "beat_res": {(0, 4): 8, (4, 12): 4},
    "num_velocities": 32,
    "special_tokens": ["PAD", "BOS", "EOS", "MASK"],
    "use_chords": False,
    "use_rests": False,
    "use_tempos": True,
    "use_time_signatures": True,
    "use_programs": False,
    "num_tempos": 32,  # number of tempo bins
    "tempo_range": (40, 250),  # (min, max)
}
config = TokenizerConfig(**TOKENIZER_PARAMS)

# Creates the tokenizer
tokenizer = CPWord(config)

# %%
tokens = tokenizer(random_midi_file)
midi2 = tokenizer(tokens)

# %%
midi2.time_signature_changes[0]
# Out:
# TimeSignature(numerator=4, denominator=4, time=0)

# %%
tokens
# Out:
# [[['Family_Metric',
#    'Bar_None',
#    'Ignore_None',
#    'Ignore_None',
#    'Ignore_None',
#    'Ignore_None',
#    'TimeSig_4/4'],
#   ['Family_Metric',
#    'Position_0',
#    'Ignore_None',
#    'Ignore_None',
#    'Ignore_None',
#    'Tempo_121.29',
#    'Ignore_None'],
#   ['Family_Note',
#    'Ignore_None',
#    'Pitch_62',
#    'Velocity_91',
#    'Duration_0.4.8',
#    'Ignore_None',
#    'Ignore_None'],
#   ['Family_Metric',
#    'Position_4',
#    'Ignore_None',
#    'Ignore_None',
#    'Ignore_None',
#    'Tempo_121.29',
#    'Ignore_None'],
#   ['Family_Note',
#    'Ignore_None',
#    'Pitch_67',
#    'Velocity_91',
#    'Duration_0.4.8',
#    'Ignore_None',
#    'Ignore_None'],
#   ['Family_Metric',
#    'Position_8',
#    'Ignore_None',
#    'Ignore_None',
#    'Ignore_None',
#    'Tempo_121.29',
#    'Ignore_None'],
#   ['Family_Note',
#    'Ignore_None',
#    'Pitch_67',
#    'Velocity_91',
#    'Duration_0.4.8',
#    'Ignore_None',
#    'Ignore_None'],
# ...

# %% [markdown]
# # List to CP Representation

# %%
import yaml
import jsonlines
import glob
import random
import json
import os

# Get the current working directory
cwd = os.getcwd()

# Change the working directory to one level up
import os
os.chdir(cwd + "/..")
print(os.getcwd())

# config_path = r"C:\Users\Keshav\Desktop\QMUL\Research\PhraseBuilder_new\PhraseBuilder\configs\configs_windows.yaml"
config_path = r"/homes/kb658/PhraseBuilder/configs/configs_os.yaml"

# Load config file
with open(config_path, 'r') as f:
    configs = yaml.safe_load(f)
    
artifact_folder = configs["raw_data"]["artifact_folder"]
mono_folder = configs["raw_data"]["mono_folder"]
json_folder = configs["raw_data"]["json_folder"]
raw_data_folders = configs["raw_data"]["raw_data_folders"]

# Get a random file from json_folder
json_files = glob.glob(json_folder + "/*.json")
random_json_file = random.choice(json_files)
print(random_json_file)

# Load the JSON file
with open(random_json_file, 'r') as f:
    data = json.load(f)
# Out:
# /homes/kb658/PhraseBuilder
# data/extracted_phrases/NLB176384_01_mono.mid.json

# %%
data['phrases']['0'][0]
# Out:
# [[0, 0, 0, 71, 0.5, 91],
#  [0, 0.5, 0, 72, 0.5, 91],
#  [0, 1.0, 0, 74, 1.0, 91],
#  [0, 2.0, 0, 71, 1.0, 91],
#  [1, 0.0, 0, 71, 1.0, 91],
#  [1, 1.0, 0, 71, 1.0, 91],
#  [1, 2.0, 0, 69, 1.0, 91]]

# %%
data["metadata"]["time_signature"]
# Out:
# 'TimeSig_3/4'

# %%
def list_to_cp_encoding(encoding, tempo_location, time_signature):
    current_bar = encoding[0][0]
    reverse_encoding = []
    for n, note in enumerate(encoding):
        if str(note) == "BOS":
            note_info = []
            note_info.append("BOS")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            reverse_encoding.append(note_info)
            continue
        elif str(note) == "EOS":
            note_info = []
            note_info.append("EOS")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            reverse_encoding.append(note_info)
            continue
        if n == 0:
            note_info = []
            note_info.append("Family_Metric")
            note_info.append("Bar_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append("Ignore_None")
            note_info.append(time_signature)
            reverse_encoding.append(note_info)
            current_bar = int(note[0])
        elif note[0] > current_bar:
            bar_diff = note[0] - current_bar
            for i in range(int(bar_diff)):
                note_info = []
                note_info.append("Family_Metric")
                note_info.append("Bar_None")
                note_info.append("Ignore_None")
                note_info.append("Ignore_None")
                note_info.append("Ignore_None")
                note_info.append("Ignore_None")
                note_info.append(time_signature)
                reverse_encoding.append(note_info)
                current_bar = note[0]
        
        note_info = []
        note_info.append("Family_Metric")
        note_info.append(f'Position_{note[1]}')
        note_info.append("Ignore_None")
        note_info.append("Ignore_None")
        note_info.append("Ignore_None")        
        # if note_info[1].startswith("Position"):
        #     note_info.append(f'Tempo_{tempo_location[str(0)]}')
        # else:
        note_info.append("Ignore_None")
        note_info.append("Ignore_None")
        reverse_encoding.append(note_info)
        
        note_info = []
        note_info.append("Family_Note")
        note_info.append("Ignore_None")
        note_info.append(f'Pitch_{note[3]}')
        note_info.append(f'Velocity_{note[5]}')
        note_info.append(f'Duration_{note[4]}')
        note_info.append("Ignore_None")
        note_info.append("Ignore_None")
        reverse_encoding.append(note_info)

    return reverse_encoding
        

encoding = data['phrases']['0'][0]
tempo_location = data["metadata"]["tempo"]
time_signature = data["metadata"]["time_signature"]
list_to_cp_encoding(encoding, tempo_location, time_signature)
# Out:
# [['Family_Metric',
#   'Bar_None',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None',
#   'TimeSig_2/4'],
#  ['Family_Metric',
#   'Position_0',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None'],
#  ['Family_Note',
#   'Ignore_None',
#   'Pitch_72',
#   'Velocity_91',
#   'Duration_1.0',
#   'Ignore_None',
#   'Ignore_None'],
#  ['Family_Metric',
#   'Position_1.0',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None'],
#  ['Family_Note',
#   'Ignore_None',
#   'Pitch_72',
#   'Velocity_91',
#   'Duration_1.0',
#   'Ignore_None',
#   'Ignore_None'],
#  ['Family_Metric',
#   'Bar_None',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None',
#   'TimeSig_2/4'],
#  ['Family_Metric',
#   'Position_0.0',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None',
#   'Ignore_None'],
#  ['Family_Note',
#   'Ignore_None',
#   'Pitch_74',
# ...

# %% [markdown]
# # Read Midi File with Music21

# %%
# %cd /homes/kb658/PhraseBuilder/utils/
# Out:
# /homes/kb658/PhraseBuilder/utils
# /homes/kb658/.conda/envs/music/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from utils import find_beats_in_bar

# %%
from music21 import converter, instrument, note, chord

def parse_midi(file_path):
    midi_data = []

    # Load MIDI file
    midi_stream = converter.parse(file_path)

    # Extract instrument parts
    parts = instrument.partitionByInstrument(midi_stream)

    if parts:
        # Iterate through each instrument part
        for part in parts.parts:
            # Reset bar number for each part
            current_bar_number = 0
            # Iterate through each note in the part
            for element in part.recurse():
                if isinstance(element, note.Note) or isinstance(element, chord.Chord):
                    # Calculate the bar number for each note/chord based on the time signature
                    offset_in_beats = element.getOffsetInHierarchy(part)  # Get offset in beats relative to the part
                    time_signature = part.getTimeSignatures()[0] if part.getTimeSignatures() else None
                    if time_signature:
                        time_sign = f"TimeSig_{time_signature.numerator}/{time_signature.denominator}"
                        beats_per_bar = find_beats_in_bar(time_sign)
                        # beats_per_bar = time_signature.numerator
                        bar_number = int(offset_in_beats / beats_per_bar)
                    else:
                        beats_per_bar = 4
                        bar_number = int(offset_in_beats / beats_per_bar)
                    current_bar_number = bar_number
                    # If it's a Note or Chord, extract relevant information and append to midi_data
                    if isinstance(element, note.Note):
                        midi_data.append([bar_number, offset_in_beats % beats_per_bar, 0, element.pitch.midi, element.duration.quarterLength, element.volume.velocity])
                    elif isinstance(element, chord.Chord):
                        continue
    return midi_data, time_signature

# Example usage:
file_path = "/homes/kb658/PhraseBuilder/data/Mono_Midi_Files/brabant1.mid"  # Change this to your MIDI file path
midi_data, time_signature = parse_midi(file_path)
print(midi_data)
print(time_signature)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from music21 import converter, instrument, note, chord
#       3 def parse_midi(file_path):
#       4     midi_data = []
#
# File ~/.conda/envs/music/lib/python3.9/site-packages/music21/__init__.py:234
#     232 from music21 import beam  # noqa: E402
#     233 from music21 import clef  # noqa: E402
# --> 234 from music21 import configure  # noqa: E402
#     235 from music21 import defaults  # noqa: E402
#     236 from music21 import derivation  # noqa: E402
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:846, in exec_module(self, module)
#
# ...
